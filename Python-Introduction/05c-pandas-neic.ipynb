# %% [markdown]
# # Working with timeseries

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('https://raw.githubusercontent.com/serivan/mldmlab/master/Datasets/neic_new.csv', parse_dates=['time'], index_col=0).tz_localize(None)
df.head(10)
# Out:
#                          latitude  ...                                 place
# time                               ...
# 1973-01-01 11:42:37.500   -35.513  ...           southern Mid-Atlantic Ridge
# 1973-01-05 13:54:29.100   -38.997  ...           North Island of New Zealand
# 1973-01-06 15:52:41.900   -14.665  ...                               Vanuatu
# 1973-01-18 09:28:14.100    -6.868  ...  New Britain region, Papua New Guinea
# 1973-01-22 00:37:58.000    18.601  ...              offshore Jalisco, Mexico
# 1973-01-27 13:08:43.700    -0.115  ...                   Sulawesi, Indonesia
# 1973-01-30 21:01:12.500    18.481  ...                     Michoacan, Mexico
# 1973-01-31 20:55:53.100    28.206  ...           Bonin Islands, Japan region
# 1973-02-01 05:14:20.600   -22.655  ...                      Jujuy, Argentina
# 1973-02-06 10:37:10.100    31.398  ...                western Sichuan, China
#
# [10 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6017 entries, 1973-01-01 11:42:37.500000 to 2015-11-11 02:46:19.900000
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   6017 non-null   float64
#  1   longitude  6017 non-null   float64
#  2   depth      6017 non-null   float64
#  3   mag        6017 non-null   float64
#  4   place      6016 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 282.0+ KB

# %%
figure(figsize=(12,4))
df.resample('Y').size().plot(marker='o')
xlabel('Year')
ylabel('Number of events');

# %%
figure(figsize=(12,4))
df['mag'].resample('Y').max().plot(marker='o')
xlabel('Year')
ylabel('Magnitude');

# %%
figure(figsize=(16, 3))
df['mag'].resample('M').count().plot()
xlabel('Time')
ylabel('Number of events per month');

# %%
figure(figsize=(12,4))
df.groupby(df.index.month).size().plot(marker='o')
xlabel('Month')
ylabel('Total number of events in month');

# %%
figure(figsize=(12,4))
df['mag'].groupby(df.index.month).max().plot(marker='o')
xlabel('Month')
ylabel('Maximum magnitude in month');
